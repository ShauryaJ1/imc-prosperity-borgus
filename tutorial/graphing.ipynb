# %%
# !pip list
# Out:
# Package           Version
# ----------------- -----------
# asttokens         3.0.0
# colorama          0.4.6
# comm              0.2.2
# contourpy         1.3.1
# cycler            0.12.1
# debugpy           1.8.13
# decorator         5.2.1
# docutils          0.21.2
# exceptiongroup    1.2.2
# executing         2.2.0
# fonttools         4.56.0
# ipykernel         6.29.5
# ipython           8.34.0
# jedi              0.19.2
# jsonpickle        4.0.2
# jupyter_client    8.6.3
# jupyter_core      5.7.2
# kiwisolver        1.4.8
# matplotlib        3.10.1
# matplotlib-inline 0.1.7
# nest-asyncio      1.6.0
# numpy             2.2.3
# packaging         24.2
# pandas            2.2.3
# parso             0.8.4
# pillow            11.1.0
# pip               23.0.1
# platformdirs      4.3.7
# prompt_toolkit    3.0.50
# psutil            7.0.0
# pure_eval         0.2.3
# Pygments          2.19.1
# pyparsing         3.2.1
# python-dateutil   2.9.0.post0
# pytz              2025.1
# pywin32           310
# pyzmq             26.3.0
# setuptools        65.5.0
# six               1.17.0
# stack-data        0.6.3
# statistics        1.0.3.5
# tornado           6.4.2
# traitlets         5.14.3
# typing            3.7.4.3
# typing_extensions 4.12.2
# tzdata            2025.1
# wcwidth           0.2.13
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("logs/mcginley_data.csv")

# %%
df.head()
# Out:
#    day  timestamp           product  bid_price_1  bid_volume_1  bid_price_2  \
# 0   -1          0  RAINFOREST_RESIN        10002             1       9996.0
# 1   -1          0              KELP         2028             1       2026.0
# 2   -1        100              KELP         2025            24          NaN
# 3   -1        100  RAINFOREST_RESIN         9996             2       9995.0
# 4   -1        200  RAINFOREST_RESIN         9995            20          NaN
#
#    bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  ask_volume_1  \
# 0           2.0       9995.0          29.0        10004             2
# 1           2.0       2025.0          29.0         2029            31
# 2           NaN          NaN           NaN         2028             2
# 3          22.0          NaN           NaN        10004             2
# 4           NaN          NaN           NaN        10005            20
#
#    ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  mid_price  \
# 0      10005.0          29.0          NaN           NaN    10003.0
# 1          NaN           NaN          NaN           NaN     2028.5
# 2       2029.0          22.0          NaN           NaN     2026.5
# 3      10005.0          22.0          NaN           NaN    10000.0
# 4          NaN           NaN          NaN           NaN    10000.0
#
#    profit_and_loss
# 0              0.0
# 1              0.0
# 2              0.0
# 3              4.0
# 4              4.0

# %%
to_plot = [(timestamp,product,mid_price) for timestamp, product, mid_price in zip(df['timestamp'], df['product'], df['mid_price'])]

# %%
to_plot[:5]
# Out:
# [(0, 'RAINFOREST_RESIN', 10003.0),
#  (0, 'KELP', 2028.5),
#  (100, 'KELP', 2026.5),
#  (100, 'RAINFOREST_RESIN', 10000.0),
#  (200, 'RAINFOREST_RESIN', 10000.0)]

# %%
resins = [i for i in to_plot if i[1] == 'RAINFOREST_RESIN']
kelps = [i for i in to_plot if i[1] == 'KELP']

# %%
len(resins)
# Out:
# 2000

# %%
len(kelps)
# Out:
# 2000

# %%
kelps[:5]
# Out:
# [(0, 'KELP', 2028.5),
#  (100, 'KELP', 2026.5),
#  (200, 'KELP', 2026.5),
#  (300, 'KELP', 2026.5),
#  (400, 'KELP', 2026.5)]

# %%
resins[:5]
# Out:
# [(0, 'RAINFOREST_RESIN', 10003.0),
#  (100, 'RAINFOREST_RESIN', 10000.0),
#  (200, 'RAINFOREST_RESIN', 10000.0),
#  (300, 'RAINFOREST_RESIN', 10000.0),
#  (400, 'RAINFOREST_RESIN', 10000.0)]

# %%
x_values = [i[0] for i in kelps][:2000]
y_values = [i[2] for i in kelps][:2000]

# Plot with markers ('o' for dots) and lines ('-' for connections)
plt.plot(x_values, y_values, label='RAINFOREST_RESIN')

# Set y-axis to log scale
# plt.xscale('log')

# Labels and legend
plt.xlabel("X-Axis Label")
plt.ylabel("Y-Axis (Log Scale)")
plt.legend()
plt.title("Resin Data with Logarithmic Y-Axis")

# Show plot
plt.show()

# %%
import re

# Define the regex pattern to match lambdaLog valu
def extract_log(p):
    pattern = r'"lambdaLog":\s*"([\d\.]+)"'

# Sample text (you would read this from the file instead)
    with open(p, "r") as file:
        log_data = file.read()

    # Find all matches
    lambda_log_values = re.findall(pattern, log_data)

    # Convert to float (if needed)
    lambda_log_values = [float(value) for value in lambda_log_values]

    # Print extracted values
    # print(lambda_log_values)
    return lambda_log_values

# %%
x_values = [i[0] for i in kelps]
y_values = [i[2] for i in kelps]

# Plot with markers ('o' for dots) and lines ('-' for connections)
plt.plot(x_values, y_values, label='KELP')
plt.plot(x_values, extract_log("logs/mcg_log.txt"), label='MCGINLEY 10', color='orange')
plt.plot(x_values, extract_log("logs/ema_log.txt"), label='EMA', color='green')
# plt.plot(x_values, [(m+e)/2 for m,e in zip(extract_log("mcg_log.txt"),extract_log("ema_log.txt"))][:100], label='avg', color='red')
# plt.plot(x_values, extract_log("mcg_20_log.txt"), label='MCGINLEY 20', color='red')
# Set y-axis to log scale
# plt.xscale('log')

# Labels and legend
plt.xlabel("X-Axis Label")
plt.ylabel("Y-Axis (Log Scale)")
plt.legend()
plt.title("Kelp Data with Logarithmic Y-Axis")

# Show plot
plt.show()

# %%
resins
# Out:
# [(0, 'RAINFOREST_RESIN', 10003.0),
#  (100, 'RAINFOREST_RESIN', 10000.0),
#  (200, 'RAINFOREST_RESIN', 10000.0),
#  (300, 'RAINFOREST_RESIN', 10000.0),
#  (400, 'RAINFOREST_RESIN', 10000.0),
#  (500, 'RAINFOREST_RESIN', 9998.5),
#  (600, 'RAINFOREST_RESIN', 10002.5),
#  (700, 'RAINFOREST_RESIN', 10000.0),
#  (800, 'RAINFOREST_RESIN', 10000.0),
#  (900, 'RAINFOREST_RESIN', 10000.0),
#  (1000, 'RAINFOREST_RESIN', 10000.0),
#  (1100, 'RAINFOREST_RESIN', 10000.0),
#  (1200, 'RAINFOREST_RESIN', 9996.5),
#  (1300, 'RAINFOREST_RESIN', 10003.0),
#  (1400, 'RAINFOREST_RESIN', 10000.0),
#  (1500, 'RAINFOREST_RESIN', 10000.0),
#  (1600, 'RAINFOREST_RESIN', 10000.0),
#  (1700, 'RAINFOREST_RESIN', 9999.0),
#  (1800, 'RAINFOREST_RESIN', 10003.0),
#  (1900, 'RAINFOREST_RESIN', 10000.0),
#  (2000, 'RAINFOREST_RESIN', 9997.0),
#  (2100, 'RAINFOREST_RESIN', 9999.0),
#  (2200, 'RAINFOREST_RESIN', 10001.0),
#  (2300, 'RAINFOREST_RESIN', 10001.0),
#  (2400, 'RAINFOREST_RESIN', 10000.0),
#  (2500, 'RAINFOREST_RESIN', 10000.0),
#  (2600, 'RAINFOREST_RESIN', 10000.0),
#  (2700, 'RAINFOREST_RESIN', 10001.5),
#  (2800, 'RAINFOREST_RESIN', 10000.0),
#  (2900, 'RAINFOREST_RESIN', 10000.0),
#  (3000, 'RAINFOREST_RESIN', 10001.5),
#  (3100, 'RAINFOREST_RESIN', 10000.0),
#  (3200, 'RAINFOREST_RESIN', 10000.0),
#  (3300, 'RAINFOREST_RESIN', 10000.0),
#  (3400, 'RAINFOREST_RESIN', 10000.0),
#  (3500, 'RAINFOREST_RESIN', 10000.0),
#  (3600, 'RAINFOREST_RESIN', 9996.5),
#  (3700, 'RAINFOREST_RESIN', 10003.0),
#  (3800, 'RAINFOREST_RESIN', 9999.0),
#  (3900, 'RAINFOREST_RESIN', 10001.0),
#  (4000, 'RAINFOREST_RESIN', 10000.0),
#  (4100, 'RAINFOREST_RESIN', 10000.0),
#  (4200, 'RAINFOREST_RESIN', 9999.0),
#  (4300, 'RAINFOREST_RESIN', 9996.5),
#  (4400, 'RAINFOREST_RESIN', 10000.0),
#  (4500, 'RAINFOREST_RESIN', 9999.0),
#  (4600, 'RAINFOREST_RESIN', 9999.0),
#  (4700, 'RAINFOREST_RESIN', 10000.0),
#  (4800, 'RAINFOREST_RESIN', 10001.0),
#  (4900, 'RAINFOREST_RESIN', 9998.5),
#  (5000, 'RAINFOREST_RESIN', 10001.0),
#  (5100, 'RAINFOREST_RESIN', 10000.0),
#  (5200, 'RAINFOREST_RESIN', 10001.0),
#  (5300, 'RAINFOREST_RESIN', 10000.0),
#  (5400, 'RAINFOREST_RESIN', 10000.0),
#  (5500, 'RAINFOREST_RESIN', 10000.0),
#  (5600, 'RAINFOREST_RESIN', 10000.0),
#  (5700, 'RAINFOREST_RESIN', 10001.5),
#  (5800, 'RAINFOREST_RESIN', 10000.0),
#  (5900, 'RAINFOREST_RESIN', 10000.0),
#  (6000, 'RAINFOREST_RESIN', 10000.0),
#  (6100, 'RAINFOREST_RESIN', 10000.0),
#  (6200, 'RAINFOREST_RESIN', 10000.0),
#  (6300, 'RAINFOREST_RESIN', 10000.0),
#  (6400, 'RAINFOREST_RESIN', 10000.0),
#  (6500, 'RAINFOREST_RESIN', 9997.0),
#  (6600, 'RAINFOREST_RESIN', 10000.0),
#  (6700, 'RAINFOREST_RESIN', 9998.5),
#  (6800, 'RAINFOREST_RESIN', 10000.0),
#  (6900, 'RAINFOREST_RESIN', 9999.0),
#  (7000, 'RAINFOREST_RESIN', 10001.5),
#  (7100, 'RAINFOREST_RESIN', 10000.0),
#  (7200, 'RAINFOREST_RESIN', 10001.0),
#  (7300, 'RAINFOREST_RESIN', 10003.0),
#  (7400, 'RAINFOREST_RESIN', 10000.0),
#  (7500, 'RAINFOREST_RESIN', 9998.5),
#  (7600, 'RAINFOREST_RESIN', 10000.0),
#  (7700, 'RAINFOREST_RESIN', 10000.0),
#  (7800, 'RAINFOREST_RESIN', 10001.0),
#  (7900, 'RAINFOREST_RESIN', 10000.0),
#  (8000, 'RAINFOREST_RESIN', 10000.0),
#  (8100, 'RAINFOREST_RESIN', 10000.0),
#  (8200, 'RAINFOREST_RESIN', 10000.0),
#  (8300, 'RAINFOREST_RESIN', 10000.0),
#  (8400, 'RAINFOREST_RESIN', 10000.0),
#  (8500, 'RAINFOREST_RESIN', 10001.0),
#  (8600, 'RAINFOREST_RESIN', 10000.0),
#  (8700, 'RAINFOREST_RESIN', 10001.5),
#  (8800, 'RAINFOREST_RESIN', 9996.5),
#  (8900, 'RAINFOREST_RESIN', 10001.5),
#  (9000, 'RAINFOREST_RESIN', 10000.0),
#  (9100, 'RAINFOREST_RESIN', 10001.0),
#  (9200, 'RAINFOREST_RESIN', 10001.5),
#  (9300, 'RAINFOREST_RESIN', 10000.0),
#  (9400, 'RAINFOREST_RESIN', 10001.0),
#  (9500, 'RAINFOREST_RESIN', 10000.0),
#  (9600, 'RAINFOREST_RESIN', 10000.0),
#  (9700, 'RAINFOREST_RESIN', 9998.5),
#  (9800, 'RAINFOREST_RESIN', 10000.0),
#  (9900, 'RAINFOREST_RESIN', 10000.0),
#  (10000, 'RAINFOREST_RESIN', 10000.0),
#  (10100, 'RAINFOREST_RESIN', 9999.0),
#  (10200, 'RAINFOREST_RESIN', 10000.0),
#  (10300, 'RAINFOREST_RESIN', 10001.5),
#  (10400, 'RAINFOREST_RESIN', 10003.0),
#  (10500, 'RAINFOREST_RESIN', 10001.0),
#  (10600, 'RAINFOREST_RESIN', 9998.0),
#  (10700, 'RAINFOREST_RESIN', 10001.5),
#  (10800, 'RAINFOREST_RESIN', 10001.0),
#  (10900, 'RAINFOREST_RESIN', 10000.0),
#  (11000, 'RAINFOREST_RESIN', 9998.5),
#  (11100, 'RAINFOREST_RESIN', 10001.5),
#  (11200, 'RAINFOREST_RESIN', 9999.0),
#  (11300, 'RAINFOREST_RESIN', 10000.0),
#  (11400, 'RAINFOREST_RESIN', 10000.0),
#  (11500, 'RAINFOREST_RESIN', 9999.0),
#  (11600, 'RAINFOREST_RESIN', 9999.0),
#  (11700, 'RAINFOREST_RESIN', 10000.0),
#  (11800, 'RAINFOREST_RESIN', 9999.0),
#  (11900, 'RAINFOREST_RESIN', 10000.0),
#  (12000, 'RAINFOREST_RESIN', 10003.5),
#  (12100, 'RAINFOREST_RESIN', 10000.0),
#  (12200, 'RAINFOREST_RESIN', 10000.0),
#  (12300, 'RAINFOREST_RESIN', 10001.0),
#  (12400, 'RAINFOREST_RESIN', 10000.0),
#  (12500, 'RAINFOREST_RESIN', 10000.0),
#  (12600, 'RAINFOREST_RESIN', 10000.0),
#  (12700, 'RAINFOREST_RESIN', 10000.0),
#  (12800, 'RAINFOREST_RESIN', 10000.0),
#  (12900, 'RAINFOREST_RESIN', 9999.0),
#  (13000, 'RAINFOREST_RESIN', 10003.5),
#  (13100, 'RAINFOREST_RESIN', 10000.0),
#  (13200, 'RAINFOREST_RESIN', 10001.5),
#  (13300, 'RAINFOREST_RESIN', 10000.0),
#  (13400, 'RAINFOREST_RESIN', 10000.0),
#  (13500, 'RAINFOREST_RESIN', 10000.0),
#  (13600, 'RAINFOREST_RESIN', 9998.5),
#  (13700, 'RAINFOREST_RESIN', 9997.0),
#  (13800, 'RAINFOREST_RESIN', 10000.0),
#  (13900, 'RAINFOREST_RESIN', 9998.0),
#  (14000, 'RAINFOREST_RESIN', 10001.0),
#  (14100, 'RAINFOREST_RESIN', 10000.0),
#  (14200, 'RAINFOREST_RESIN', 10000.0),
#  (14300, 'RAINFOREST_RESIN', 10000.0),
#  (14400, 'RAINFOREST_RESIN', 10000.0),
#  (14500, 'RAINFOREST_RESIN', 9998.5),
#  (14600, 'RAINFOREST_RESIN', 9998.0),
#  (14700, 'RAINFOREST_RESIN', 9998.5),
#  (14800, 'RAINFOREST_RESIN', 9998.5),
#  (14900, 'RAINFOREST_RESIN', 10002.5),
#  (15000, 'RAINFOREST_RESIN', 10001.5),
#  (15100, 'RAINFOREST_RESIN', 10000.0),
#  (15200, 'RAINFOREST_RESIN', 10001.5),
#  (15300, 'RAINFOREST_RESIN', 9998.5),
#  (15400, 'RAINFOREST_RESIN', 9997.0),
#  (15500, 'RAINFOREST_RESIN', 10003.0),
#  (15600, 'RAINFOREST_RESIN', 10000.0),
#  (15700, 'RAINFOREST_RESIN', 10003.0),
#  (15800, 'RAINFOREST_RESIN', 10001.0),
#  (15900, 'RAINFOREST_RESIN', 9998.0),
#  (16000, 'RAINFOREST_RESIN', 9999.0),
#  (16100, 'RAINFOREST_RESIN', 9997.5),
#  (16200, 'RAINFOREST_RESIN', 9996.5),
#  (16300, 'RAINFOREST_RESIN', 10000.0),
#  (16400, 'RAINFOREST_RESIN', 9999.0),
#  (16500, 'RAINFOREST_RESIN', 9999.0),
#  (16600, 'RAINFOREST_RESIN', 10001.0),
#  (16700, 'RAINFOREST_RESIN', 10003.5),
#  (16800, 'RAINFOREST_RESIN', 10000.0),
#  (16900, 'RAINFOREST_RESIN', 10000.0),
#  (17000, 'RAINFOREST_RESIN', 10001.5),
#  (17100, 'RAINFOREST_RESIN', 10000.0),
#  (17200, 'RAINFOREST_RESIN', 10001.0),
#  (17300, 'RAINFOREST_RESIN', 9999.0),
#  (17400, 'RAINFOREST_RESIN', 10002.5),
#  (17500, 'RAINFOREST_RESIN', 10000.0),
#  (17600, 'RAINFOREST_RESIN', 10001.5),
#  (17700, 'RAINFOREST_RESIN', 10000.0),
#  (17800, 'RAINFOREST_RESIN', 9999.0),
#  (17900, 'RAINFOREST_RESIN', 10000.0),
#  (18000, 'RAINFOREST_RESIN', 10000.0),
#  (18100, 'RAINFOREST_RESIN', 10000.0),
#  (18200, 'RAINFOREST_RESIN', 10000.0),
#  (18300, 'RAINFOREST_RESIN', 10000.0),
#  (18400, 'RAINFOREST_RESIN', 10000.0),
#  (18500, 'RAINFOREST_RESIN', 9997.5),
#  (18600, 'RAINFOREST_RESIN', 10003.5),
#  (18700, 'RAINFOREST_RESIN', 10000.0),
#  (18800, 'RAINFOREST_RESIN', 10000.0),
#  (18900, 'RAINFOREST_RESIN', 10001.5),
#  (19000, 'RAINFOREST_RESIN', 10000.0),
#  (19100, 'RAINFOREST_RESIN', 10000.0),
#  (19200, 'RAINFOREST_RESIN', 9997.0),
#  (19300, 'RAINFOREST_RESIN', 10000.0),
#  (19400, 'RAINFOREST_RESIN', 10000.0),
#  (19500, 'RAINFOREST_RESIN', 10000.0),
#  (19600, 'RAINFOREST_RESIN', 10000.0),
#  (19700, 'RAINFOREST_RESIN', 10003.0),
#  (19800, 'RAINFOREST_RESIN', 10000.0),
#  (19900, 'RAINFOREST_RESIN', 10000.0),
#  (20000, 'RAINFOREST_RESIN', 9998.5),
#  (20100, 'RAINFOREST_RESIN', 10003.0),
#  (20200, 'RAINFOREST_RESIN', 9996.5),
#  (20300, 'RAINFOREST_RESIN', 10000.0),
#  (20400, 'RAINFOREST_RESIN', 9998.0),
#  (20500, 'RAINFOREST_RESIN', 10002.0),
#  (20600, 'RAINFOREST_RESIN', 10000.0),
#  (20700, 'RAINFOREST_RESIN', 10003.5),
#  (20800, 'RAINFOREST_RESIN', 10000.0),
#  (20900, 'RAINFOREST_RESIN', 10000.0),
#  (21000, 'RAINFOREST_RESIN', 10000.0),
#  (21100, 'RAINFOREST_RESIN', 10000.0),
#  (21200, 'RAINFOREST_RESIN', 9996.5),
#  (21300, 'RAINFOREST_RESIN', 9999.0),
#  (21400, 'RAINFOREST_RESIN', 10000.0),
#  (21500, 'RAINFOREST_RESIN', 10000.0),
#  (21600, 'RAINFOREST_RESIN', 10003.0),
#  (21700, 'RAINFOREST_RESIN', 10001.0),
#  (21800, 'RAINFOREST_RESIN', 10000.0),
#  (21900, 'RAINFOREST_RESIN', 10003.0),
#  (22000, 'RAINFOREST_RESIN', 10000.0),
#  (22100, 'RAINFOREST_RESIN', 9999.0),
#  (22200, 'RAINFOREST_RESIN', 10001.0),
#  (22300, 'RAINFOREST_RESIN', 10000.0),
#  (22400, 'RAINFOREST_RESIN', 9997.0),
#  (22500, 'RAINFOREST_RESIN', 10000.0),
#  (22600, 'RAINFOREST_RESIN', 10002.0),
#  (22700, 'RAINFOREST_RESIN', 10000.0),
#  (22800, 'RAINFOREST_RESIN', 9997.0),
#  (22900, 'RAINFOREST_RESIN', 9999.0),
#  (23000, 'RAINFOREST_RESIN', 10000.0),
#  (23100, 'RAINFOREST_RESIN', 10001.5),
#  (23200, 'RAINFOREST_RESIN', 10001.0),
#  (23300, 'RAINFOREST_RESIN', 10000.0),
#  (23400, 'RAINFOREST_RESIN', 10000.0),
#  (23500, 'RAINFOREST_RESIN', 10001.0),
#  (23600, 'RAINFOREST_RESIN', 10000.0),
#  (23700, 'RAINFOREST_RESIN', 10003.0),
#  (23800, 'RAINFOREST_RESIN', 10000.0),
#  (23900, 'RAINFOREST_RESIN', 10000.0),
#  (24000, 'RAINFOREST_RESIN', 10001.5),
#  (24100, 'RAINFOREST_RESIN', 10000.0),
#  (24200, 'RAINFOREST_RESIN', 9999.0),
#  (24300, 'RAINFOREST_RESIN', 9999.0),
#  (24400, 'RAINFOREST_RESIN', 10003.0),
#  (24500, 'RAINFOREST_RESIN', 10003.0),
#  (24600, 'RAINFOREST_RESIN', 9996.5),
#  (24700, 'RAINFOREST_RESIN', 10000.0),
#  (24800, 'RAINFOREST_RESIN', 10000.0),
#  (24900, 'RAINFOREST_RESIN', 10003.0),
#  (25000, 'RAINFOREST_RESIN', 10000.0),
#  (25100, 'RAINFOREST_RESIN', 10003.5),
#  (25200, 'RAINFOREST_RESIN', 9997.0),
#  (25300, 'RAINFOREST_RESIN', 10000.0),
#  (25400, 'RAINFOREST_RESIN', 10000.0),
#  (25500, 'RAINFOREST_RESIN', 9997.0),
#  (25600, 'RAINFOREST_RESIN', 9999.0),
#  (25700, 'RAINFOREST_RESIN', 10000.0),
#  (25800, 'RAINFOREST_RESIN', 10003.5),
#  (25900, 'RAINFOREST_RESIN', 10000.0),
#  (26000, 'RAINFOREST_RESIN', 10000.0),
#  (26100, 'RAINFOREST_RESIN', 10001.5),
#  (26200, 'RAINFOREST_RESIN', 10000.0),
#  (26300, 'RAINFOREST_RESIN', 9997.0),
#  (26400, 'RAINFOREST_RESIN', 10000.0),
#  (26500, 'RAINFOREST_RESIN', 10000.0),
#  (26600, 'RAINFOREST_RESIN', 9997.0),
#  (26700, 'RAINFOREST_RESIN', 10001.0),
#  (26800, 'RAINFOREST_RESIN', 10000.0),
#  (26900, 'RAINFOREST_RESIN', 10003.5),
#  (27000, 'RAINFOREST_RESIN', 9998.5),
#  (27100, 'RAINFOREST_RESIN', 10000.0),
#  (27200, 'RAINFOREST_RESIN', 10001.5),
#  (27300, 'RAINFOREST_RESIN', 10000.0),
#  (27400, 'RAINFOREST_RESIN', 10000.0),
#  (27500, 'RAINFOREST_RESIN', 10000.0),
#  (27600, 'RAINFOREST_RESIN', 10001.5),
#  (27700, 'RAINFOREST_RESIN', 10000.0),
#  (27800, 'RAINFOREST_RESIN', 10001.0),
#  (27900, 'RAINFOREST_RESIN', 9999.0),
#  (28000, 'RAINFOREST_RESIN', 10001.5),
#  (28100, 'RAINFOREST_RESIN', 10000.0),
#  (28200, 'RAINFOREST_RESIN', 9997.0),
#  (28300, 'RAINFOREST_RESIN', 10000.0),
#  (28400, 'RAINFOREST_RESIN', 10000.0),
#  (28500, 'RAINFOREST_RESIN', 10001.5),
#  (28600, 'RAINFOREST_RESIN', 10003.0),
#  (28700, 'RAINFOREST_RESIN', 10000.0),
#  (28800, 'RAINFOREST_RESIN', 10000.0),
#  (28900, 'RAINFOREST_RESIN', 10001.0),
#  (29000, 'RAINFOREST_RESIN', 10000.0),
#  (29100, 'RAINFOREST_RESIN', 10000.0),
#  (29200, 'RAINFOREST_RESIN', 10000.0),
#  (29300, 'RAINFOREST_RESIN', 9999.0),
#  (29400, 'RAINFOREST_RESIN', 10003.0),
#  (29500, 'RAINFOREST_RESIN', 10000.0),
#  (29600, 'RAINFOREST_RESIN', 10000.0),
#  (29700, 'RAINFOREST_RESIN', 9999.0),
#  (29800, 'RAINFOREST_RESIN', 10001.0),
#  (29900, 'RAINFOREST_RESIN', 10000.0),
#  (30000, 'RAINFOREST_RESIN', 10001.0),
#  (30100, 'RAINFOREST_RESIN', 10000.0),
#  (30200, 'RAINFOREST_RESIN', 10000.0),
#  (30300, 'RAINFOREST_RESIN', 9999.0),
#  (30400, 'RAINFOREST_RESIN', 10001.0),
#  (30500, 'RAINFOREST_RESIN', 10001.0),
#  (30600, 'RAINFOREST_RESIN', 9999.0),
#  (30700, 'RAINFOREST_RESIN', 10000.0),
#  (30800, 'RAINFOREST_RESIN', 10000.0),
#  (30900, 'RAINFOREST_RESIN', 9999.0),
#  (31000, 'RAINFOREST_RESIN', 10002.0),
#  (31100, 'RAINFOREST_RESIN', 10000.0),
#  (31200, 'RAINFOREST_RESIN', 9999.0),
#  (31300, 'RAINFOREST_RESIN', 10000.0),
#  (31400, 'RAINFOREST_RESIN', 9996.5),
#  (31500, 'RAINFOREST_RESIN', 10000.0),
#  (31600, 'RAINFOREST_RESIN', 10000.0),
#  (31700, 'RAINFOREST_RESIN', 10000.0),
#  (31800, 'RAINFOREST_RESIN', 10002.0),
#  (31900, 'RAINFOREST_RESIN', 10001.5),
#  (32000, 'RAINFOREST_RESIN', 10000.0),
#  (32100, 'RAINFOREST_RESIN', 10000.0),
#  (32200, 'RAINFOREST_RESIN', 10000.0),
#  (32300, 'RAINFOREST_RESIN', 10000.0),
#  (32400, 'RAINFOREST_RESIN', 10000.0),
#  (32500, 'RAINFOREST_RESIN', 10001.0),
#  (32600, 'RAINFOREST_RESIN', 10003.5),
#  (32700, 'RAINFOREST_RESIN', 10000.0),
#  (32800, 'RAINFOREST_RESIN', 10000.0),
#  (32900, 'RAINFOREST_RESIN', 10000.0),
#  (33000, 'RAINFOREST_RESIN', 10000.0),
#  (33100, 'RAINFOREST_RESIN', 10000.0),
#  (33200, 'RAINFOREST_RESIN', 9999.0),
#  (33300, 'RAINFOREST_RESIN', 10000.0),
#  (33400, 'RAINFOREST_RESIN', 9999.0),
#  (33500, 'RAINFOREST_RESIN', 10000.0),
#  (33600, 'RAINFOREST_RESIN', 10003.5),
#  (33700, 'RAINFOREST_RESIN', 9999.0),
#  (33800, 'RAINFOREST_RESIN', 10000.0),
#  (33900, 'RAINFOREST_RESIN', 10000.0),
#  (34000, 'RAINFOREST_RESIN', 10003.5),
#  (34100, 'RAINFOREST_RESIN', 10000.0),
#  (34200, 'RAINFOREST_RESIN', 10000.0),
#  (34300, 'RAINFOREST_RESIN', 10003.0),
#  (34400, 'RAINFOREST_RESIN', 10000.0),
#  (34500, 'RAINFOREST_RESIN', 10000.0),
#  (34600, 'RAINFOREST_RESIN', 10000.0),
#  (34700, 'RAINFOREST_RESIN', 10001.5),
#  (34800, 'RAINFOREST_RESIN', 10000.0),
#  (34900, 'RAINFOREST_RESIN', 10000.0),
#  (35000, 'RAINFOREST_RESIN', 10003.5),
#  (35100, 'RAINFOREST_RESIN', 10003.0),
#  (35200, 'RAINFOREST_RESIN', 9999.0),
#  (35300, 'RAINFOREST_RESIN', 10001.0),
#  (35400, 'RAINFOREST_RESIN', 10003.5),
#  (35500, 'RAINFOREST_RESIN', 10000.0),
#  (35600, 'RAINFOREST_RESIN', 10000.0),
#  (35700, 'RAINFOREST_RESIN', 10000.0),
#  (35800, 'RAINFOREST_RESIN', 10001.0),
#  (35900, 'RAINFOREST_RESIN', 10000.0),
#  (36000, 'RAINFOREST_RESIN', 9998.5),
#  (36100, 'RAINFOREST_RESIN', 10003.0),
#  (36200, 'RAINFOREST_RESIN', 9997.0),
#  (36300, 'RAINFOREST_RESIN', 10000.0),
#  (36400, 'RAINFOREST_RESIN', 10001.0),
#  (36500, 'RAINFOREST_RESIN', 10000.0),
#  (36600, 'RAINFOREST_RESIN', 10000.0),
#  (36700, 'RAINFOREST_RESIN', 10000.0),
#  (36800, 'RAINFOREST_RESIN', 10000.0),
#  (36900, 'RAINFOREST_RESIN', 10000.0),
#  (37000, 'RAINFOREST_RESIN', 10000.0),
#  (37100, 'RAINFOREST_RESIN', 10000.0),
#  (37200, 'RAINFOREST_RESIN', 10000.0),
#  (37300, 'RAINFOREST_RESIN', 9997.0),
#  (37400, 'RAINFOREST_RESIN', 10003.5),
#  (37500, 'RAINFOREST_RESIN', 10000.0),
#  (37600, 'RAINFOREST_RESIN', 9998.5),
#  (37700, 'RAINFOREST_RESIN', 10000.0),
#  (37800, 'RAINFOREST_RESIN', 10000.0),
#  (37900, 'RAINFOREST_RESIN', 10000.0),
#  (38000, 'RAINFOREST_RESIN', 10003.0),
#  (38100, 'RAINFOREST_RESIN', 9999.0),
#  (38200, 'RAINFOREST_RESIN', 10000.0),
#  (38300, 'RAINFOREST_RESIN', 10001.5),
#  (38400, 'RAINFOREST_RESIN', 9998.0),
#  (38500, 'RAINFOREST_RESIN', 10003.5),
#  (38600, 'RAINFOREST_RESIN', 10000.0),
#  (38700, 'RAINFOREST_RESIN', 10000.0),
#  (38800, 'RAINFOREST_RESIN', 9999.0),
#  (38900, 'RAINFOREST_RESIN', 10000.0),
#  (39000, 'RAINFOREST_RESIN', 9998.5),
#  (39100, 'RAINFOREST_RESIN', 10001.0),
#  (39200, 'RAINFOREST_RESIN', 10000.0),
#  (39300, 'RAINFOREST_RESIN', 10000.0),
#  (39400, 'RAINFOREST_RESIN', 10000.0),
#  (39500, 'RAINFOREST_RESIN', 9996.5),
#  (39600, 'RAINFOREST_RESIN', 10000.0),
#  (39700, 'RAINFOREST_RESIN', 10000.0),
#  (39800, 'RAINFOREST_RESIN', 10000.0),
#  (39900, 'RAINFOREST_RESIN', 9999.0),
#  (40000, 'RAINFOREST_RESIN', 10000.0),
#  (40100, 'RAINFOREST_RESIN', 9999.0),
#  (40200, 'RAINFOREST_RESIN', 10000.0),
#  (40300, 'RAINFOREST_RESIN', 9996.5),
#  (40400, 'RAINFOREST_RESIN', 10000.0),
#  (40500, 'RAINFOREST_RESIN', 10003.0),
#  (40600, 'RAINFOREST_RESIN', 10000.0),
#  (40700, 'RAINFOREST_RESIN', 10001.0),
#  (40800, 'RAINFOREST_RESIN', 10000.0),
#  (40900, 'RAINFOREST_RESIN', 10001.0),
#  (41000, 'RAINFOREST_RESIN', 9998.5),
#  (41100, 'RAINFOREST_RESIN', 10000.0),
#  (41200, 'RAINFOREST_RESIN', 10000.0),
#  (41300, 'RAINFOREST_RESIN', 10001.0),
#  (41400, 'RAINFOREST_RESIN', 9999.0),
#  (41500, 'RAINFOREST_RESIN', 10001.0),
#  (41600, 'RAINFOREST_RESIN', 10000.0),
#  (41700, 'RAINFOREST_RESIN', 10002.5),
#  (41800, 'RAINFOREST_RESIN', 10000.0),
#  (41900, 'RAINFOREST_RESIN', 9997.0),
#  (42000, 'RAINFOREST_RESIN', 10000.0),
#  (42100, 'RAINFOREST_RESIN', 10001.0),
#  (42200, 'RAINFOREST_RESIN', 10003.5),
#  (42300, 'RAINFOREST_RESIN', 10000.0),
#  (42400, 'RAINFOREST_RESIN', 10000.0),
#  (42500, 'RAINFOREST_RESIN', 9998.5),
#  (42600, 'RAINFOREST_RESIN', 10000.0),
#  (42700, 'RAINFOREST_RESIN', 10000.0),
#  (42800, 'RAINFOREST_RESIN', 10000.0),
#  (42900, 'RAINFOREST_RESIN', 10000.0),
#  (43000, 'RAINFOREST_RESIN', 10000.0),
#  (43100, 'RAINFOREST_RESIN', 10000.0),
#  (43200, 'RAINFOREST_RESIN', 10000.0),
#  (43300, 'RAINFOREST_RESIN', 10000.0),
#  (43400, 'RAINFOREST_RESIN', 10000.0),
#  (43500, 'RAINFOREST_RESIN', 10001.5),
#  (43600, 'RAINFOREST_RESIN', 9999.0),
#  (43700, 'RAINFOREST_RESIN', 10000.0),
#  (43800, 'RAINFOREST_RESIN', 10000.0),
#  (43900, 'RAINFOREST_RESIN', 10003.0),
#  (44000, 'RAINFOREST_RESIN', 10000.0),
#  (44100, 'RAINFOREST_RESIN', 9996.5),
#  (44200, 'RAINFOREST_RESIN', 10000.0),
#  (44300, 'RAINFOREST_RESIN', 10000.0),
#  (44400, 'RAINFOREST_RESIN', 10001.5),
#  (44500, 'RAINFOREST_RESIN', 10000.0),
#  (44600, 'RAINFOREST_RESIN', 10000.0),
#  (44700, 'RAINFOREST_RESIN', 9998.5),
#  (44800, 'RAINFOREST_RESIN', 9996.5),
#  (44900, 'RAINFOREST_RESIN', 10000.0),
#  (45000, 'RAINFOREST_RESIN', 10003.0),
#  (45100, 'RAINFOREST_RESIN', 10000.0),
#  (45200, 'RAINFOREST_RESIN', 10000.0),
#  (45300, 'RAINFOREST_RESIN', 10000.0),
#  (45400, 'RAINFOREST_RESIN', 9997.0),
#  (45500, 'RAINFOREST_RESIN', 9998.0),
#  (45600, 'RAINFOREST_RESIN', 9998.5),
#  (45700, 'RAINFOREST_RESIN', 10000.0),
#  (45800, 'RAINFOREST_RESIN', 10000.0),
#  (45900, 'RAINFOREST_RESIN', 10000.0),
#  (46000, 'RAINFOREST_RESIN', 10000.0),
#  (46100, 'RAINFOREST_RESIN', 10001.0),
#  (46200, 'RAINFOREST_RESIN', 10001.0),
#  (46300, 'RAINFOREST_RESIN', 10000.0),
#  (46400, 'RAINFOREST_RESIN', 10000.0),
#  (46500, 'RAINFOREST_RESIN', 10002.0),
#  (46600, 'RAINFOREST_RESIN', 10001.0),
#  (46700, 'RAINFOREST_RESIN', 10000.0),
#  (46800, 'RAINFOREST_RESIN', 10000.0),
#  (46900, 'RAINFOREST_RESIN', 10000.0),
#  (47000, 'RAINFOREST_RESIN', 10000.0),
#  (47100, 'RAINFOREST_RESIN', 9997.0),
#  (47200, 'RAINFOREST_RESIN', 10003.0),
#  (47300, 'RAINFOREST_RESIN', 10003.5),
#  (47400, 'RAINFOREST_RESIN', 9998.5),
#  (47500, 'RAINFOREST_RESIN', 9998.5),
#  (47600, 'RAINFOREST_RESIN', 10000.0),
#  (47700, 'RAINFOREST_RESIN', 9999.0),
#  (47800, 'RAINFOREST_RESIN', 9999.0),
#  (47900, 'RAINFOREST_RESIN', 10003.5),
#  (48000, 'RAINFOREST_RESIN', 10000.0),
#  (48100, 'RAINFOREST_RESIN', 9998.5),
#  (48200, 'RAINFOREST_RESIN', 10001.5),
#  (48300, 'RAINFOREST_RESIN', 9997.0),
#  (48400, 'RAINFOREST_RESIN', 9998.5),
#  (48500, 'RAINFOREST_RESIN', 9996.5),
#  (48600, 'RAINFOREST_RESIN', 10000.0),
#  (48700, 'RAINFOREST_RESIN', 10000.0),
#  (48800, 'RAINFOREST_RESIN', 10000.0),
#  (48900, 'RAINFOREST_RESIN', 10000.0),
#  (49000, 'RAINFOREST_RESIN', 10000.0),
#  (49100, 'RAINFOREST_RESIN', 10000.0),
#  (49200, 'RAINFOREST_RESIN', 10000.0),
#  (49300, 'RAINFOREST_RESIN', 10001.0),
#  (49400, 'RAINFOREST_RESIN', 10000.0),
#  (49500, 'RAINFOREST_RESIN', 10000.0),
#  (49600, 'RAINFOREST_RESIN', 10000.0),
#  (49700, 'RAINFOREST_RESIN', 10001.0),
#  (49800, 'RAINFOREST_RESIN', 10000.0),
#  (49900, 'RAINFOREST_RESIN', 10001.5),
#  (50000, 'RAINFOREST_RESIN', 10000.0),
#  (50100, 'RAINFOREST_RESIN', 10000.0),
#  (50200, 'RAINFOREST_RESIN', 10000.0),
#  (50300, 'RAINFOREST_RESIN', 9998.5),
#  (50400, 'RAINFOREST_RESIN', 9999.0),
#  (50500, 'RAINFOREST_RESIN', 10000.0),
#  (50600, 'RAINFOREST_RESIN', 10003.0),
#  (50700, 'RAINFOREST_RESIN', 10000.0),
#  (50800, 'RAINFOREST_RESIN', 10003.0),
#  (50900, 'RAINFOREST_RESIN', 10000.0),
#  (51000, 'RAINFOREST_RESIN', 10000.0),
#  (51100, 'RAINFOREST_RESIN', 10001.0),
#  (51200, 'RAINFOREST_RESIN', 10000.0),
#  (51300, 'RAINFOREST_RESIN', 10000.0),
#  (51400, 'RAINFOREST_RESIN', 9998.5),
#  (51500, 'RAINFOREST_RESIN', 10000.0),
#  (51600, 'RAINFOREST_RESIN', 10001.0),
#  (51700, 'RAINFOREST_RESIN', 10000.0),
#  (51800, 'RAINFOREST_RESIN', 10000.0),
#  (51900, 'RAINFOREST_RESIN', 10000.0),
#  (52000, 'RAINFOREST_RESIN', 10001.5),
#  (52100, 'RAINFOREST_RESIN', 10000.0),
#  (52200, 'RAINFOREST_RESIN', 10000.0),
#  (52300, 'RAINFOREST_RESIN', 10003.0),
#  (52400, 'RAINFOREST_RESIN', 10001.0),
#  (52500, 'RAINFOREST_RESIN', 9997.0),
#  (52600, 'RAINFOREST_RESIN', 9999.0),
#  (52700, 'RAINFOREST_RESIN', 10000.0),
#  (52800, 'RAINFOREST_RESIN', 10000.0),
#  (52900, 'RAINFOREST_RESIN', 10000.0),
#  (53000, 'RAINFOREST_RESIN', 10003.0),
#  (53100, 'RAINFOREST_RESIN', 10000.0),
#  (53200, 'RAINFOREST_RESIN', 10000.0),
#  (53300, 'RAINFOREST_RESIN', 10000.0),
#  (53400, 'RAINFOREST_RESIN', 10001.0),
#  (53500, 'RAINFOREST_RESIN', 9999.0),
#  (53600, 'RAINFOREST_RESIN', 9996.5),
#  (53700, 'RAINFOREST_RESIN', 10001.5),
#  (53800, 'RAINFOREST_RESIN', 10003.5),
#  (53900, 'RAINFOREST_RESIN', 10000.0),
#  (54000, 'RAINFOREST_RESIN', 10001.0),
#  (54100, 'RAINFOREST_RESIN', 10001.0),
#  (54200, 'RAINFOREST_RESIN', 10000.0),
#  (54300, 'RAINFOREST_RESIN', 10000.0),
#  (54400, 'RAINFOREST_RESIN', 10000.0),
#  (54500, 'RAINFOREST_RESIN', 10000.0),
#  (54600, 'RAINFOREST_RESIN', 10003.5),
#  (54700, 'RAINFOREST_RESIN', 10000.0),
#  (54800, 'RAINFOREST_RESIN', 10001.5),
#  (54900, 'RAINFOREST_RESIN', 9999.0),
#  (55000, 'RAINFOREST_RESIN', 9999.0),
#  (55100, 'RAINFOREST_RESIN', 10000.0),
#  (55200, 'RAINFOREST_RESIN', 10000.0),
#  (55300, 'RAINFOREST_RESIN', 9997.0),
#  (55400, 'RAINFOREST_RESIN', 10001.0),
#  (55500, 'RAINFOREST_RESIN', 9998.5),
#  (55600, 'RAINFOREST_RESIN', 10000.0),
#  (55700, 'RAINFOREST_RESIN', 10000.0),
#  (55800, 'RAINFOREST_RESIN', 10001.0),
#  (55900, 'RAINFOREST_RESIN', 10000.0),
#  (56000, 'RAINFOREST_RESIN', 9999.0),
#  (56100, 'RAINFOREST_RESIN', 10000.0),
#  (56200, 'RAINFOREST_RESIN', 10000.0),
#  (56300, 'RAINFOREST_RESIN', 10003.0),
#  (56400, 'RAINFOREST_RESIN', 10000.0),
#  (56500, 'RAINFOREST_RESIN', 10000.0),
#  (56600, 'RAINFOREST_RESIN', 9999.0),
#  (56700, 'RAINFOREST_RESIN', 9999.0),
#  (56800, 'RAINFOREST_RESIN', 10003.0),
#  (56900, 'RAINFOREST_RESIN', 10000.0),
#  (57000, 'RAINFOREST_RESIN', 10000.0),
#  (57100, 'RAINFOREST_RESIN', 10000.0),
#  (57200, 'RAINFOREST_RESIN', 10003.0),
#  (57300, 'RAINFOREST_RESIN', 9999.0),
#  (57400, 'RAINFOREST_RESIN', 10000.0),
#  (57500, 'RAINFOREST_RESIN', 10001.0),
#  (57600, 'RAINFOREST_RESIN', 10000.0),
#  (57700, 'RAINFOREST_RESIN', 10000.0),
#  (57800, 'RAINFOREST_RESIN', 10001.0),
#  (57900, 'RAINFOREST_RESIN', 9997.0),
#  (58000, 'RAINFOREST_RESIN', 9997.0),
#  (58100, 'RAINFOREST_RESIN', 10000.0),
#  (58200, 'RAINFOREST_RESIN', 10000.0),
#  (58300, 'RAINFOREST_RESIN', 10000.0),
#  (58400, 'RAINFOREST_RESIN', 10000.0),
#  (58500, 'RAINFOREST_RESIN', 9998.5),
#  (58600, 'RAINFOREST_RESIN', 10003.5),
#  (58700, 'RAINFOREST_RESIN', 10000.0),
#  (58800, 'RAINFOREST_RESIN', 9998.5),
#  (58900, 'RAINFOREST_RESIN', 10000.0),
#  (59000, 'RAINFOREST_RESIN', 10000.0),
#  (59100, 'RAINFOREST_RESIN', 10000.0),
#  (59200, 'RAINFOREST_RESIN', 10001.0),
#  (59300, 'RAINFOREST_RESIN', 10000.0),
#  (59400, 'RAINFOREST_RESIN', 10000.0),
#  (59500, 'RAINFOREST_RESIN', 10003.5),
#  (59600, 'RAINFOREST_RESIN', 10000.0),
#  (59700, 'RAINFOREST_RESIN', 10000.0),
#  (59800, 'RAINFOREST_RESIN', 10000.0),
#  (59900, 'RAINFOREST_RESIN', 9999.0),
#  (60000, 'RAINFOREST_RESIN', 10001.5),
#  (60100, 'RAINFOREST_RESIN', 10000.0),
#  (60200, 'RAINFOREST_RESIN', 10000.0),
#  (60300, 'RAINFOREST_RESIN', 10000.0),
#  (60400, 'RAINFOREST_RESIN', 9997.0),
#  (60500, 'RAINFOREST_RESIN', 10000.0),
#  (60600, 'RAINFOREST_RESIN', 10000.0),
#  (60700, 'RAINFOREST_RESIN', 10000.0),
#  (60800, 'RAINFOREST_RESIN', 10003.0),
#  (60900, 'RAINFOREST_RESIN', 10000.0),
#  (61000, 'RAINFOREST_RESIN', 10000.0),
#  (61100, 'RAINFOREST_RESIN', 10000.0),
#  (61200, 'RAINFOREST_RESIN', 9999.0),
#  (61300, 'RAINFOREST_RESIN', 10000.0),
#  (61400, 'RAINFOREST_RESIN', 10000.0),
#  (61500, 'RAINFOREST_RESIN', 10000.0),
#  (61600, 'RAINFOREST_RESIN', 10000.0),
#  (61700, 'RAINFOREST_RESIN', 10000.0),
#  (61800, 'RAINFOREST_RESIN', 10000.0),
#  (61900, 'RAINFOREST_RESIN', 9996.5),
#  (62000, 'RAINFOREST_RESIN', 10000.0),
#  (62100, 'RAINFOREST_RESIN', 10000.0),
#  (62200, 'RAINFOREST_RESIN', 9998.5),
#  (62300, 'RAINFOREST_RESIN', 10000.0),
#  (62400, 'RAINFOREST_RESIN', 10000.0),
#  (62500, 'RAINFOREST_RESIN', 10000.0),
#  (62600, 'RAINFOREST_RESIN', 10000.0),
#  (62700, 'RAINFOREST_RESIN', 10000.0),
#  (62800, 'RAINFOREST_RESIN', 10000.0),
#  (62900, 'RAINFOREST_RESIN', 9997.0),
#  (63000, 'RAINFOREST_RESIN', 10000.0),
#  (63100, 'RAINFOREST_RESIN', 10000.0),
#  (63200, 'RAINFOREST_RESIN', 10000.0),
#  (63300, 'RAINFOREST_RESIN', 10000.0),
#  (63400, 'RAINFOREST_RESIN', 10000.0),
#  (63500, 'RAINFOREST_RESIN', 10001.5),
#  (63600, 'RAINFOREST_RESIN', 10000.0),
#  (63700, 'RAINFOREST_RESIN', 9999.0),
#  (63800, 'RAINFOREST_RESIN', 10000.0),
#  (63900, 'RAINFOREST_RESIN', 10000.0),
#  (64000, 'RAINFOREST_RESIN', 10001.5),
#  (64100, 'RAINFOREST_RESIN', 9998.5),
#  (64200, 'RAINFOREST_RESIN', 10000.0),
#  (64300, 'RAINFOREST_RESIN', 10001.0),
#  (64400, 'RAINFOREST_RESIN', 10001.0),
#  (64500, 'RAINFOREST_RESIN', 10001.0),
#  (64600, 'RAINFOREST_RESIN', 10000.0),
#  (64700, 'RAINFOREST_RESIN', 10000.0),
#  (64800, 'RAINFOREST_RESIN', 10000.0),
#  (64900, 'RAINFOREST_RESIN', 10000.0),
#  (65000, 'RAINFOREST_RESIN', 9996.5),
#  (65100, 'RAINFOREST_RESIN', 10000.0),
#  (65200, 'RAINFOREST_RESIN', 10001.5),
#  (65300, 'RAINFOREST_RESIN', 9998.5),
#  (65400, 'RAINFOREST_RESIN', 9998.0),
#  (65500, 'RAINFOREST_RESIN', 10000.0),
#  (65600, 'RAINFOREST_RESIN', 10001.5),
#  (65700, 'RAINFOREST_RESIN', 10000.0),
#  (65800, 'RAINFOREST_RESIN', 10001.5),
#  (65900, 'RAINFOREST_RESIN', 10000.0),
#  (66000, 'RAINFOREST_RESIN', 10001.0),
#  (66100, 'RAINFOREST_RESIN', 9997.0),
#  (66200, 'RAINFOREST_RESIN', 10003.5),
#  (66300, 'RAINFOREST_RESIN', 10000.0),
#  (66400, 'RAINFOREST_RESIN', 9996.5),
#  (66500, 'RAINFOREST_RESIN', 10000.0),
#  (66600, 'RAINFOREST_RESIN', 10000.0),
#  (66700, 'RAINFOREST_RESIN', 10001.5),
#  (66800, 'RAINFOREST_RESIN', 10000.0),
#  (66900, 'RAINFOREST_RESIN', 10001.5),
#  (67000, 'RAINFOREST_RESIN', 10000.0),
#  (67100, 'RAINFOREST_RESIN', 10000.0),
#  (67200, 'RAINFOREST_RESIN', 9999.0),
#  (67300, 'RAINFOREST_RESIN', 9996.5),
#  (67400, 'RAINFOREST_RESIN', 10001.0),
#  (67500, 'RAINFOREST_RESIN', 10000.0),
#  (67600, 'RAINFOREST_RESIN', 10000.0),
#  (67700, 'RAINFOREST_RESIN', 10000.0),
#  (67800, 'RAINFOREST_RESIN', 10001.5),
#  (67900, 'RAINFOREST_RESIN', 10000.0),
#  (68000, 'RAINFOREST_RESIN', 10000.0),
#  (68100, 'RAINFOREST_RESIN', 10000.0),
#  (68200, 'RAINFOREST_RESIN', 10000.0),
#  (68300, 'RAINFOREST_RESIN', 10000.0),
#  (68400, 'RAINFOREST_RESIN', 10000.0),
#  (68500, 'RAINFOREST_RESIN', 9998.5),
#  (68600, 'RAINFOREST_RESIN', 10000.0),
#  (68700, 'RAINFOREST_RESIN', 10000.0),
#  (68800, 'RAINFOREST_RESIN', 9996.5),
#  (68900, 'RAINFOREST_RESIN', 10000.0),
#  (69000, 'RAINFOREST_RESIN', 10000.0),
#  (69100, 'RAINFOREST_RESIN', 10001.0),
#  (69200, 'RAINFOREST_RESIN', 10000.0),
#  (69300, 'RAINFOREST_RESIN', 9996.5),
#  (69400, 'RAINFOREST_RESIN', 10003.0),
#  (69500, 'RAINFOREST_RESIN', 10001.0),
#  (69600, 'RAINFOREST_RESIN', 10000.0),
#  (69700, 'RAINFOREST_RESIN', 10003.0),
#  (69800, 'RAINFOREST_RESIN', 10000.0),
#  (69900, 'RAINFOREST_RESIN', 10000.0),
#  (70000, 'RAINFOREST_RESIN', 10000.0),
#  (70100, 'RAINFOREST_RESIN', 10000.0),
#  (70200, 'RAINFOREST_RESIN', 10000.0),
#  (70300, 'RAINFOREST_RESIN', 9997.0),
#  (70400, 'RAINFOREST_RESIN', 10000.0),
#  (70500, 'RAINFOREST_RESIN', 9997.5),
#  (70600, 'RAINFOREST_RESIN', 10000.0),
#  (70700, 'RAINFOREST_RESIN', 10000.0),
#  (70800, 'RAINFOREST_RESIN', 10003.5),
#  (70900, 'RAINFOREST_RESIN', 10000.0),
#  (71000, 'RAINFOREST_RESIN', 9999.0),
#  (71100, 'RAINFOREST_RESIN', 10001.0),
#  (71200, 'RAINFOREST_RESIN', 10003.0),
#  (71300, 'RAINFOREST_RESIN', 9999.0),
#  (71400, 'RAINFOREST_RESIN', 9999.0),
#  (71500, 'RAINFOREST_RESIN', 10003.0),
#  (71600, 'RAINFOREST_RESIN', 9997.0),
#  (71700, 'RAINFOREST_RESIN', 10000.0),
#  (71800, 'RAINFOREST_RESIN', 10003.0),
#  (71900, 'RAINFOREST_RESIN', 10003.0),
#  (72000, 'RAINFOREST_RESIN', 10000.0),
#  (72100, 'RAINFOREST_RESIN', 10000.0),
#  (72200, 'RAINFOREST_RESIN', 10000.0),
#  (72300, 'RAINFOREST_RESIN', 9999.0),
#  (72400, 'RAINFOREST_RESIN', 10003.0),
#  (72500, 'RAINFOREST_RESIN', 10000.0),
#  (72600, 'RAINFOREST_RESIN', 10000.0),
#  (72700, 'RAINFOREST_RESIN', 10000.0),
#  (72800, 'RAINFOREST_RESIN', 10000.0),
#  (72900, 'RAINFOREST_RESIN', 10001.0),
#  (73000, 'RAINFOREST_RESIN', 9999.0),
#  (73100, 'RAINFOREST_RESIN', 9999.0),
#  (73200, 'RAINFOREST_RESIN', 10000.0),
#  (73300, 'RAINFOREST_RESIN', 10000.0),
#  (73400, 'RAINFOREST_RESIN', 9996.5),
#  (73500, 'RAINFOREST_RESIN', 10000.0),
#  (73600, 'RAINFOREST_RESIN', 10000.0),
#  (73700, 'RAINFOREST_RESIN', 10000.0),
#  (73800, 'RAINFOREST_RESIN', 10000.0),
#  (73900, 'RAINFOREST_RESIN', 10000.0),
#  (74000, 'RAINFOREST_RESIN', 10003.0),
#  (74100, 'RAINFOREST_RESIN', 10002.0),
#  (74200, 'RAINFOREST_RESIN', 9999.0),
#  (74300, 'RAINFOREST_RESIN', 9999.0),
#  (74400, 'RAINFOREST_RESIN', 10000.0),
#  (74500, 'RAINFOREST_RESIN', 10002.5),
#  (74600, 'RAINFOREST_RESIN', 10003.5),
#  (74700, 'RAINFOREST_RESIN', 10000.0),
#  (74800, 'RAINFOREST_RESIN', 10001.0),
#  (74900, 'RAINFOREST_RESIN', 10003.0),
#  (75000, 'RAINFOREST_RESIN', 9996.5),
#  (75100, 'RAINFOREST_RESIN', 10000.0),
#  (75200, 'RAINFOREST_RESIN', 10001.0),
#  (75300, 'RAINFOREST_RESIN', 10000.0),
#  (75400, 'RAINFOREST_RESIN', 10000.0),
#  (75500, 'RAINFOREST_RESIN', 10000.0),
#  (75600, 'RAINFOREST_RESIN', 10003.0),
#  (75700, 'RAINFOREST_RESIN', 10000.0),
#  (75800, 'RAINFOREST_RESIN', 10001.0),
#  (75900, 'RAINFOREST_RESIN', 9998.5),
#  (76000, 'RAINFOREST_RESIN', 10001.0),
#  (76100, 'RAINFOREST_RESIN', 9997.0),
#  (76200, 'RAINFOREST_RESIN', 10000.0),
#  (76300, 'RAINFOREST_RESIN', 10000.0),
#  (76400, 'RAINFOREST_RESIN', 10001.5),
#  (76500, 'RAINFOREST_RESIN', 10000.0),
#  (76600, 'RAINFOREST_RESIN', 10000.0),
#  (76700, 'RAINFOREST_RESIN', 10000.0),
#  (76800, 'RAINFOREST_RESIN', 10000.0),
#  (76900, 'RAINFOREST_RESIN', 10001.5),
#  (77000, 'RAINFOREST_RESIN', 9999.0),
#  (77100, 'RAINFOREST_RESIN', 10002.0),
#  (77200, 'RAINFOREST_RESIN', 10000.0),
#  (77300, 'RAINFOREST_RESIN', 10000.0),
#  (77400, 'RAINFOREST_RESIN', 9998.5),
#  (77500, 'RAINFOREST_RESIN', 10000.0),
#  (77600, 'RAINFOREST_RESIN', 10000.0),
#  (77700, 'RAINFOREST_RESIN', 10000.0),
#  (77800, 'RAINFOREST_RESIN', 10000.0),
#  (77900, 'RAINFOREST_RESIN', 10003.0),
#  (78000, 'RAINFOREST_RESIN', 9996.5),
#  (78100, 'RAINFOREST_RESIN', 10003.0),
#  (78200, 'RAINFOREST_RESIN', 10001.5),
#  (78300, 'RAINFOREST_RESIN', 10000.0),
#  (78400, 'RAINFOREST_RESIN', 10000.0),
#  (78500, 'RAINFOREST_RESIN', 10001.0),
#  (78600, 'RAINFOREST_RESIN', 9998.5),
#  (78700, 'RAINFOREST_RESIN', 9997.0),
#  (78800, 'RAINFOREST_RESIN', 10003.5),
#  (78900, 'RAINFOREST_RESIN', 10003.5),
#  (79000, 'RAINFOREST_RESIN', 10001.5),
#  (79100, 'RAINFOREST_RESIN', 10000.0),
#  (79200, 'RAINFOREST_RESIN', 9997.0),
#  (79300, 'RAINFOREST_RESIN', 10001.0),
#  (79400, 'RAINFOREST_RESIN', 10001.0),
#  (79500, 'RAINFOREST_RESIN', 10000.0),
#  (79600, 'RAINFOREST_RESIN', 9998.5),
#  (79700, 'RAINFOREST_RESIN', 10000.0),
#  (79800, 'RAINFOREST_RESIN', 10003.5),
#  (79900, 'RAINFOREST_RESIN', 10001.0),
#  (80000, 'RAINFOREST_RESIN', 10000.0),
#  (80100, 'RAINFOREST_RESIN', 10000.0),
#  (80200, 'RAINFOREST_RESIN', 10000.0),
#  (80300, 'RAINFOREST_RESIN', 10000.0),
#  (80400, 'RAINFOREST_RESIN', 10000.0),
#  (80500, 'RAINFOREST_RESIN', 9998.0),
#  (80600, 'RAINFOREST_RESIN', 9999.0),
#  (80700, 'RAINFOREST_RESIN', 10000.0),
#  (80800, 'RAINFOREST_RESIN', 9999.0),
#  (80900, 'RAINFOREST_RESIN', 9998.5),
#  (81000, 'RAINFOREST_RESIN', 10000.0),
#  (81100, 'RAINFOREST_RESIN', 10000.0),
#  (81200, 'RAINFOREST_RESIN', 10000.0),
#  (81300, 'RAINFOREST_RESIN', 10000.0),
#  (81400, 'RAINFOREST_RESIN', 10000.0),
#  (81500, 'RAINFOREST_RESIN', 10000.0),
#  (81600, 'RAINFOREST_RESIN', 10000.0),
#  (81700, 'RAINFOREST_RESIN', 10000.0),
#  (81800, 'RAINFOREST_RESIN', 10003.0),
#  (81900, 'RAINFOREST_RESIN', 9997.0),
#  (82000, 'RAINFOREST_RESIN', 10000.0),
#  (82100, 'RAINFOREST_RESIN', 10000.0),
#  (82200, 'RAINFOREST_RESIN', 10003.0),
#  (82300, 'RAINFOREST_RESIN', 10000.0),
#  (82400, 'RAINFOREST_RESIN', 10000.0),
#  (82500, 'RAINFOREST_RESIN', 10000.0),
#  (82600, 'RAINFOREST_RESIN', 9999.0),
#  (82700, 'RAINFOREST_RESIN', 10001.0),
#  (82800, 'RAINFOREST_RESIN', 9999.0),
#  (82900, 'RAINFOREST_RESIN', 9996.5),
#  (83000, 'RAINFOREST_RESIN', 10000.0),
#  (83100, 'RAINFOREST_RESIN', 9997.0),
#  (83200, 'RAINFOREST_RESIN', 10000.0),
#  (83300, 'RAINFOREST_RESIN', 10000.0),
#  (83400, 'RAINFOREST_RESIN', 9999.0),
#  (83500, 'RAINFOREST_RESIN', 10000.0),
#  (83600, 'RAINFOREST_RESIN', 10000.0),
#  (83700, 'RAINFOREST_RESIN', 10000.0),
#  (83800, 'RAINFOREST_RESIN', 10000.0),
#  (83900, 'RAINFOREST_RESIN', 10000.0),
#  (84000, 'RAINFOREST_RESIN', 9997.0),
#  (84100, 'RAINFOREST_RESIN', 10000.0),
#  (84200, 'RAINFOREST_RESIN', 10000.0),
#  (84300, 'RAINFOREST_RESIN', 10001.0),
#  (84400, 'RAINFOREST_RESIN', 10000.0),
#  (84500, 'RAINFOREST_RESIN', 10001.0),
#  (84600, 'RAINFOREST_RESIN', 9997.0),
#  (84700, 'RAINFOREST_RESIN', 10000.0),
#  (84800, 'RAINFOREST_RESIN', 10000.0),
#  (84900, 'RAINFOREST_RESIN', 10000.0),
#  (85000, 'RAINFOREST_RESIN', 9996.5),
#  (85100, 'RAINFOREST_RESIN', 10000.0),
#  (85200, 'RAINFOREST_RESIN', 10000.0),
#  (85300, 'RAINFOREST_RESIN', 10000.0),
#  (85400, 'RAINFOREST_RESIN', 10000.0),
#  (85500, 'RAINFOREST_RESIN', 9999.0),
#  (85600, 'RAINFOREST_RESIN', 10000.0),
#  (85700, 'RAINFOREST_RESIN', 10003.0),
#  (85800, 'RAINFOREST_RESIN', 9999.0),
#  (85900, 'RAINFOREST_RESIN', 9997.0),
#  (86000, 'RAINFOREST_RESIN', 10002.0),
#  (86100, 'RAINFOREST_RESIN', 10003.0),
#  (86200, 'RAINFOREST_RESIN', 10000.0),
#  (86300, 'RAINFOREST_RESIN', 10001.5),
#  (86400, 'RAINFOREST_RESIN', 10000.0),
#  (86500, 'RAINFOREST_RESIN', 10001.0),
#  (86600, 'RAINFOREST_RESIN', 10000.0),
#  (86700, 'RAINFOREST_RESIN', 10002.5),
#  (86800, 'RAINFOREST_RESIN', 10003.0),
#  (86900, 'RAINFOREST_RESIN', 10000.0),
#  (87000, 'RAINFOREST_RESIN', 10000.0),
#  (87100, 'RAINFOREST_RESIN', 10000.0),
#  (87200, 'RAINFOREST_RESIN', 10000.0),
#  (87300, 'RAINFOREST_RESIN', 10000.0),
#  (87400, 'RAINFOREST_RESIN', 10000.0),
#  (87500, 'RAINFOREST_RESIN', 10000.0),
#  (87600, 'RAINFOREST_RESIN', 10001.5),
#  (87700, 'RAINFOREST_RESIN', 10000.0),
#  (87800, 'RAINFOREST_RESIN', 10001.5),
#  (87900, 'RAINFOREST_RESIN', 10000.0),
#  (88000, 'RAINFOREST_RESIN', 10000.0),
#  (88100, 'RAINFOREST_RESIN', 9997.0),
#  (88200, 'RAINFOREST_RESIN', 10003.0),
#  (88300, 'RAINFOREST_RESIN', 10001.0),
#  (88400, 'RAINFOREST_RESIN', 9998.5),
#  (88500, 'RAINFOREST_RESIN', 10003.5),
#  (88600, 'RAINFOREST_RESIN', 9997.5),
#  (88700, 'RAINFOREST_RESIN', 10001.5),
#  (88800, 'RAINFOREST_RESIN', 10001.0),
#  (88900, 'RAINFOREST_RESIN', 10000.0),
#  (89000, 'RAINFOREST_RESIN', 10000.0),
#  (89100, 'RAINFOREST_RESIN', 10001.0),
#  (89200, 'RAINFOREST_RESIN', 9999.0),
#  (89300, 'RAINFOREST_RESIN', 10001.0),
#  (89400, 'RAINFOREST_RESIN', 10001.5),
#  (89500, 'RAINFOREST_RESIN', 10000.0),
#  (89600, 'RAINFOREST_RESIN', 10000.0),
#  (89700, 'RAINFOREST_RESIN', 10000.0),
#  (89800, 'RAINFOREST_RESIN', 10001.5),
#  (89900, 'RAINFOREST_RESIN', 10000.0),
#  (90000, 'RAINFOREST_RESIN', 10001.0),
#  (90100, 'RAINFOREST_RESIN', 9999.0),
#  (90200, 'RAINFOREST_RESIN', 9998.5),
#  (90300, 'RAINFOREST_RESIN', 10001.0),
#  (90400, 'RAINFOREST_RESIN', 9999.0),
#  (90500, 'RAINFOREST_RESIN', 10001.5),
#  (90600, 'RAINFOREST_RESIN', 10000.0),
#  (90700, 'RAINFOREST_RESIN', 10003.0),
#  (90800, 'RAINFOREST_RESIN', 10000.0),
#  (90900, 'RAINFOREST_RESIN', 10000.0),
#  (91000, 'RAINFOREST_RESIN', 10000.0),
#  (91100, 'RAINFOREST_RESIN', 10000.0),
#  (91200, 'RAINFOREST_RESIN', 9998.5),
#  (91300, 'RAINFOREST_RESIN', 9998.5),
#  (91400, 'RAINFOREST_RESIN', 10000.0),
#  (91500, 'RAINFOREST_RESIN', 10001.5),
#  (91600, 'RAINFOREST_RESIN', 10002.5),
#  (91700, 'RAINFOREST_RESIN', 9997.0),
#  (91800, 'RAINFOREST_RESIN', 10000.0),
#  (91900, 'RAINFOREST_RESIN', 10001.0),
#  (92000, 'RAINFOREST_RESIN', 10001.5),
#  (92100, 'RAINFOREST_RESIN', 9996.5),
#  (92200, 'RAINFOREST_RESIN', 10000.0),
#  (92300, 'RAINFOREST_RESIN', 9997.0),
#  (92400, 'RAINFOREST_RESIN', 10000.0),
#  (92500, 'RAINFOREST_RESIN', 10000.0),
#  (92600, 'RAINFOREST_RESIN', 10000.0),
#  (92700, 'RAINFOREST_RESIN', 10003.0),
#  (92800, 'RAINFOREST_RESIN', 10000.0),
#  (92900, 'RAINFOREST_RESIN', 10001.0),
#  (93000, 'RAINFOREST_RESIN', 10000.0),
#  (93100, 'RAINFOREST_RESIN', 10000.0),
#  (93200, 'RAINFOREST_RESIN', 9996.5),
#  (93300, 'RAINFOREST_RESIN', 9998.5),
#  (93400, 'RAINFOREST_RESIN', 9997.0),
#  (93500, 'RAINFOREST_RESIN', 10002.0),
#  (93600, 'RAINFOREST_RESIN', 10000.0),
#  (93700, 'RAINFOREST_RESIN', 10003.0),
#  (93800, 'RAINFOREST_RESIN', 9996.5),
#  (93900, 'RAINFOREST_RESIN', 10000.0),
#  (94000, 'RAINFOREST_RESIN', 10003.0),
#  (94100, 'RAINFOREST_RESIN', 10000.0),
#  (94200, 'RAINFOREST_RESIN', 9998.5),
#  (94300, 'RAINFOREST_RESIN', 10003.0),
#  (94400, 'RAINFOREST_RESIN', 10000.0),
#  (94500, 'RAINFOREST_RESIN', 10000.0),
#  (94600, 'RAINFOREST_RESIN', 10001.5),
#  (94700, 'RAINFOREST_RESIN', 10003.0),
#  (94800, 'RAINFOREST_RESIN', 10000.0),
#  (94900, 'RAINFOREST_RESIN', 9996.5),
#  (95000, 'RAINFOREST_RESIN', 10001.0),
#  (95100, 'RAINFOREST_RESIN', 10000.0),
#  (95200, 'RAINFOREST_RESIN', 10000.0),
#  (95300, 'RAINFOREST_RESIN', 9998.5),
#  (95400, 'RAINFOREST_RESIN', 9998.5),
#  (95500, 'RAINFOREST_RESIN', 9999.0),
#  (95600, 'RAINFOREST_RESIN', 10000.0),
#  (95700, 'RAINFOREST_RESIN', 10003.0),
#  (95800, 'RAINFOREST_RESIN', 10000.0),
#  (95900, 'RAINFOREST_RESIN', 10001.0),
#  (96000, 'RAINFOREST_RESIN', 10000.0),
#  (96100, 'RAINFOREST_RESIN', 10000.0),
#  (96200, 'RAINFOREST_RESIN', 9997.0),
#  (96300, 'RAINFOREST_RESIN', 10000.0),
#  (96400, 'RAINFOREST_RESIN', 10001.5),
#  (96500, 'RAINFOREST_RESIN', 10001.0),
#  (96600, 'RAINFOREST_RESIN', 9998.5),
#  (96700, 'RAINFOREST_RESIN', 9999.0),
#  (96800, 'RAINFOREST_RESIN', 10003.0),
#  (96900, 'RAINFOREST_RESIN', 10000.0),
#  (97000, 'RAINFOREST_RESIN', 10000.0),
#  (97100, 'RAINFOREST_RESIN', 9998.5),
#  (97200, 'RAINFOREST_RESIN', 9998.0),
#  (97300, 'RAINFOREST_RESIN', 10001.0),
#  (97400, 'RAINFOREST_RESIN', 10000.0),
#  (97500, 'RAINFOREST_RESIN', 10000.0),
#  (97600, 'RAINFOREST_RESIN', 9999.0),
#  (97700, 'RAINFOREST_RESIN', 10000.0),
#  (97800, 'RAINFOREST_RESIN', 9998.5),
#  (97900, 'RAINFOREST_RESIN', 10000.0),
#  (98000, 'RAINFOREST_RESIN', 10000.0),
#  (98100, 'RAINFOREST_RESIN', 9997.0),
#  (98200, 'RAINFOREST_RESIN', 10000.0),
#  (98300, 'RAINFOREST_RESIN', 10000.0),
#  (98400, 'RAINFOREST_RESIN', 10000.0),
#  (98500, 'RAINFOREST_RESIN', 10000.0),
#  (98600, 'RAINFOREST_RESIN', 10000.0),
#  (98700, 'RAINFOREST_RESIN', 10000.0),
#  (98800, 'RAINFOREST_RESIN', 10003.0),
#  (98900, 'RAINFOREST_RESIN', 10001.5),
#  (99000, 'RAINFOREST_RESIN', 10000.0),
#  (99100, 'RAINFOREST_RESIN', 10000.0),
#  (99200, 'RAINFOREST_RESIN', 10000.0),
#  (99300, 'RAINFOREST_RESIN', 10000.0),
#  (99400, 'RAINFOREST_RESIN', 10000.0),
#  (99500, 'RAINFOREST_RESIN', 10000.0),
#  (99600, 'RAINFOREST_RESIN', 10003.5),
#  (99700, 'RAINFOREST_RESIN', 10000.0),
#  (99800, 'RAINFOREST_RESIN', 10000.0),
#  (99900, 'RAINFOREST_RESIN', 10003.5),
#  ...]

# %%
plt.plot(x_values,[resin[-1] for resin in resins],label='RAINFOREST_RESIN')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
