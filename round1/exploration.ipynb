# %%
import pandas as pd

# %%
df1 = pd.read_csv('tutorial/squid_ink_fair_val.csv', sep=';')

# %%
print(df1.columns[0])
# Out:
# day

# %%
! pip install plotly
import plotly.graph_objects as go
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: C:\Users\samar\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
print(df1)
# Out:
#       day  timestamp           product  bid_price_1  bid_volume_1  \
# 0       0          0  RAINFOREST_RESIN         9998             9
# 1       0          0              KELP         2028            23
# 2       0          0         SQUID_INK         1968            23
# 3       0        100         SQUID_INK         1970             1
# 4       0        100              KELP         2031             1
# ...   ...        ...               ...          ...           ...
# 2995    0      99800              KELP         2028            26
# 2996    0      99800         SQUID_INK         1967            26
# 2997    0      99900              KELP         2028            27
# 2998    0      99900         SQUID_INK         1967            27
# 2999    0      99900  RAINFOREST_RESIN         9998             6
#
#       bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 0          9995.0          23.0          NaN           NaN        10005
# ...

# %% [markdown]
# SQUID INK INVESTIGATION

# %%
import numpy as np

squid_rows = [i for i in range(len(df1)) if df1.loc[i, 'product'] == 'SQUID_INK']

timestamps = df1.loc[squid_rows, 'timestamp'].values
mid_price = df1.loc[squid_rows, 'mid_price'].values
fair_value = df1.loc[squid_rows, 'profit_and_loss'].values + np.array([1970])

fig = go.Figure()
fig.add_trace(go.Scatter(x=timestamps, y=mid_price, mode='lines', name='Mid Price'))
fig.add_trace(go.Scatter(x=timestamps, y=fair_value, mode='lines', name='Fair Value'))

fig.update_layout(
    title='Fair Value and Mid Price',
    xaxis_title='Timestamp',
    yaxis_title='Price'
)
fig.show()
# Out:
# <div>                            <div id="cd097a8c-d101-451b-873a-9ba109cfa11c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd097a8c-d101-451b-873a-9ba109cfa11c")) {                    Plotly.newPlot(                        "cd097a8c-d101-451b-873a-9ba109cfa11c",                        [{"mode":"lines","name":"Mid Price","x":[0,100,200,300,400,500,600,700,800,900,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2100,2200,2300,2400,2500,2600,2700,2800,2900,3000,3100,3200,3300,3400,3500,3600,3700,3800,3900,4000,4100,4200,4300,4400,4500,4600,4700,4800,4900,5000,5100,5200,5300,5400,5500,5600,5700,5800,5900,6000,6100,6200,6300,6400,6500,6600,6700,6800,6900,7000,7100,7200,7300,7400,7500,7600,7700,7800,7900,8000,8100,8200,8300,8400,8500,8600,8700
# ...

# %%
fig2 = go.Figure()

fig2.add_trace(go.Scatter(x=timestamps, y=mid_price-fair_value, mode='lines', name='Delta'))
fig2.update_layout(
    title='Delta between Mid Price and Fair', 
    xaxis_title='Timestamp',
    yaxis_title='Price'
)

fig2.show()
# Out:
# <div>                            <div id="de4fac60-6d43-4b02-af2a-825b9a62e9df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de4fac60-6d43-4b02-af2a-825b9a62e9df")) {                    Plotly.newPlot(                        "de4fac60-6d43-4b02-af2a-825b9a62e9df",                        [{"mode":"lines","name":"Delta","x":[0,100,200,300,400,500,600,700,800,900,1000,1100,1200,1300,1400,1500,1600,1700,1800,1900,2000,2100,2200,2300,2400,2500,2600,2700,2800,2900,3000,3100,3200,3300,3400,3500,3600,3700,3800,3900,4000,4100,4200,4300,4400,4500,4600,4700,4800,4900,5000,5100,5200,5300,5400,5500,5600,5700,5800,5900,6000,6100,6200,6300,6400,6500,6600,6700,6800,6900,7000,7100,7200,7300,7400,7500,7600,7700,7800,7900,8000,8100,8200,8300,8400,8500,8600,8700,880
# ...

# %%
import jsonpickle

# %%
with open("fair_value.txt", "w+") as f:
    f.write(str(fair_value))
